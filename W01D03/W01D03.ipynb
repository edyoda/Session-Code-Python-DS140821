# %%
Data Types:
    int 55,-67,90
    float 56.78,-0.09
    str 'apple','40', "I'am", """This is also "String" Example"""
    dict {'apple':30, 'mango':60}  key:value pairs.
    bool
    list
    None
    set
    tuple
    
Note: All the above ones are python reserved keywords. They should not be used
    in names. There are more reserved keywords which we will add later.

# %%
type('a')
# Out:
# str

# %%
a = 10.5
print(type(a))
# Out:
# <class 'float'>

# %%
## Data Type Conversion:
Converting one datatype into another.
Note: We can not convert every data type into another data type.

# %%
x = 57
print('type of x',type(x))
y = float(x) # converting x into float
print(y)
print('type of y',type(y))
# Out:
# type of x <class 'int'>
# 57.0
# type of y <class 'float'>

# %%
x = '40'
print('type of x',type(x))
y = int(x) # converting x into int
print(y)
print('type of y',type(y))
# Out:
# type of x <class 'str'>
# 40
# type of y <class 'int'>

# %%
x = '40Aksthatha'
print('type of x',type(x))
y = int(x) # converting x into int
print(y)
print('type of y',type(y))
# Out:
# type of x <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-c866bc12d863> in <module>
#       1 x = '40Aksthatha'
#       2 print('type of x',type(x))
# ----> 3 y = int(x) # converting x into int
#       4 print(y)
#       5 print('type of y',type(y))
#
# ValueError: invalid literal for int() with base 10: '40Aksthatha'

# %%
a="25"
b=int(a)/5
c=int(b)
print(c)
# Out:
# 5

# %%
float = (0.35, 0.3636)
print(type(float))
print(float)
# Out:
# <class 'tuple'>
# (0.35, 0.3636)

# %%
x = 57
print('type of x',type(x))
y = float(x) # converting x into float
print(y)
print('type of y',type(y))
# Out:
# type of x <class 'int'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-847fd8a626ba> in <module>
#       1 x = 57
#       2 print('type of x',type(x))
# ----> 3 y = float(x) # converting x into float
#       4 print(y)
#       5 print('type of y',type(y))
#
# TypeError: 'tuple' object is not callable

# %%
int = 5

# %%
x = '4'
y = int(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7ff611eb3306> in <module>
#       1 x = '4'
# ----> 2 y = int(x)
#       3 print(y)
#
# TypeError: 'int' object is not callable

# %%
x = 56
y = float(x)
print(y)
# Out:
# 56.0

# %%
a = "shyam"

# %%
a="'vishal','yash','shubham'"

# %%
type(a)
# Out:
# str

# %%
a
# Out:
# "'vishal','yash','shubham'"

# %%
x= "'Mango', '567'"

# %%
type(x)
# Out:
# str

# %%
name = 'abhishek','Bunty'

# %%
x = {name:abc,agw:2}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-82fb115cc474> in <module>
# ----> 1 x = {name:abc,agw:2}
#
# NameError: name 'name' is not defined

# %%
a = {'summit':34,'rhgav':20}

# %%
# I am not audible. Okay don't worry. I'll reconnect within 2 minutes.

# %%
p= {'pavan', 'swamy'}

# %%
x = """This is also "String" Example"""
print(type(x))
print(x)
# Out:
# <class 'str'>
# This is also "String" Example

# %%
x = {'apple':30, 'mango':60}

# %%
x = """I'am "String" Example"""

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
print(x)
# Out:
# I'am "String" Example

# %%
{"name":"abc"}
# Out:
# {'name': 'abc'}

# %%
sss = 23
pavan={"pavan":3,'padh':sss}

# %%
print(type(pavan))
# Out:
# <class 'dict'>

# %%
x = {'Name':'Labhansh', 'Surname':'Garg'}
print(type(x))
# Out:
# <class 'dict'>

# %%
{'happy':34,'glad':55}
# Out:
# {'happy': 34, 'glad': 55}

# %%
Immutable/Uneditable Data Types:
    tuple
    int
    float
    str
    None
    bool
    
Mutable/Editable Data Types:
    list
    dict
    set

# %%
# x = {key:value}

key should be unique and immutable.

# %%
x = {True:40, (3,4):500, 'apple':60, 6:'six', 4.5:'four_point_five','True':500}

# %%
print(type(x))
# Out:
# <class 'dict'>

# %%
print(x)
# Out:
# {True: 40, (3, 4): 500, 'apple': 60, 6: 'six', 4.5: 'four_point_five', 'True': 500}
