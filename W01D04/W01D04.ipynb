# %%
Revision:
    Data Types:
        
    Why do we need Data Types?
    To use memory efficiently we should have different data types to store different types of data.
    
1) User defined
2) Builtin/Predefined

Builtin Data Types:
    1) int (Numbers without decimal points)
    2) float (Decimal point numbers)
    3) str (Collection of characters) (Characters are everything you see on keyboard.)
     '', "", """""" , ''''''
    4) list (Collection of different data types) (Editable/Mutable) []
    5) tuple (Colleciton of different data types) (Uneditable/Immutable) ()
    6) dict (Collection of key:value pairs) (Mutable) {'python':3}
    key should be unique and immutable.
    value can be of any data type.
    7) set (Collection of unique elements) (Mutable) {12,3,4,5}
    elements should be unqiue and immutable.
    8) bool (True or False)
    9) None (null)

# %%
Immutable:
    int
    float
    tuple
    None
    bool
    str
    
Mutable:
    set
    dict
    list

# %%
Which one of these could not be a key in dict?
1) int
2) dict
3) tuple
4) str

# %%
z = {2:'two', 'apple':50, (3,4):'three,four'}
print(type(z))
# Out:
# <class 'dict'>

# %%
t = {1:'one'}
print(type(t))
# Out:
# <class 'dict'>

# %%
z = {2:'two', 'apple':50, (3,4):'three,four', {1:'one'}:'dict_is_a_key_here'}
print(type(z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5703d53d41f6> in <module>
# ----> 1 z = {2:'two', 'apple':50, (3,4):'three,four', {1:'one'}:'dict_is_a_key_here'}
#       2 print(type(z))
#
# TypeError: unhashable type: 'dict'

# %%
list1 = [1,'one']
print(type(list1))
# Out:
# <class 'list'>

# %%
z = {2:'two', 'apple':50, (3,4):'three,four', [1,'one']:'dict_is_a_key_here'}
print(type(z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-1fdd028db0b9> in <module>
# ----> 1 z = {2:'two', 'apple':50, (3,4):'three,four', [1,'one']:'dict_is_a_key_here'}
#       2 print(type(z))
#
# TypeError: unhashable type: 'list'

# %%
z = {2:'two', 'apple':50, (3,4):'three,four', {1,'one'}:'dict_is_a_key_here'}
print(type(z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c9f48360277e> in <module>
# ----> 1 z = {2:'two', 'apple':50, (3,4):'three,four', {1,'one'}:'dict_is_a_key_here'}
#       2 print(type(z))
#
# TypeError: unhashable type: 'set'

# %%
x = {[1,2],4}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-20634699c784> in <module>
# ----> 1 x = {[1,2],4}
#
# TypeError: unhashable type: 'list'

# %%
y = {{'python':3},'java'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-90d852926d06> in <module>
# ----> 1 y = {{'python':3},'java'}
#
# TypeError: unhashable type: 'dict'

# %%
y = {{'python',3},'java'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-99cdd59dcac2> in <module>
# ----> 1 y = {{'python',3},'java'}
#
# TypeError: unhashable type: 'set'

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
x = {None:40}
print(x)
# Out:
# {None: 40}

# %%
# how do you create a null set?
x = set()

print(type(x))
print(x)
# Out:
# <class 'set'>
# set()

# %%
x = ''
print(type(x))
# Out:
# <class 'str'>

# %%
x = "mohit"
X = 30

print(x,X)
# Out:
# mohit 30

# %% [markdown]
# # Indexing

# %%
x = ['apple','mango','kiwi','banana']

# Index Position starts with 0 in python.s

# %%
x[0]
# Out:
# 'apple'

# %%
x[1]
# Out:
# 'mango'

# %%
x[2]
# Out:
# 'kiwi'

# %%
x[3]
# Out:
# 'banana'

# %%
x[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-cedd7ac36334> in <module>
# ----> 1 x[4]
#
# IndexError: list index out of range

# %% [markdown]
# # Negative Indexing

# %%
x = ['apple','mango','kiwi','banana']

# %%
x[-1]
# Out:
# 'banana'

# %%
x[-2]
# Out:
# 'kiwi'

# %%
x[-3]
# Out:
# 'mango'

# %%
x[-4]
# Out:
# 'apple'

# %%
x[-5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-3f8aa68a9513> in <module>
# ----> 1 x[-5]
#
# IndexError: list index out of range

# %%
x = [100,90,96,98,93]

y = sorted(x,reverse=True)
print(y)
print(y[-3])
# Out:
# [100, 98, 96, 93, 90]
# 96

# %%
We can do indexing in these data types:
    1) list
    2) str
    3) tuple

# %%
x = 'Mango123$#~!'

# %%
x[0]
# Out:
# 'M'

# %%
x[7]
# Out:
# '3'

# %%
x[9]
# Out:
# '#'

# %%
x[-1]
# Out:
# '!'

# %%
x = ('apple','mango','kiwi','banana')
print(type(x))
# Out:
# <class 'tuple'>

# %%
x[0]
# Out:
# 'apple'

# %%
x[-1]
# Out:
# 'banana'

# %%
# how to access items in dict?
# ans => with key, because keys are unique and hashing automatically converts
# a key into a position for the value of that key.

# %%
x = {'python':3,'java':8,'aalu':'sona'}

# %%
x['python']
# Out:
# 3

# %%
x['java']
# Out:
# 8

# %%
x['aalu']
# Out:
# 'sona'

# %%
x = {'apple':4,'mango':4}

# %%
x[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-cedd7ac36334> in <module>
# ----> 1 x[4]
#
# KeyError: 4

# %%
x = {'apple':4,'mango':4, 'kiwi':5}

# %%
x.items()
# Out:
# dict_items([('apple', 4), ('mango', 4), ('kiwi', 5)])

# %% [markdown]
# # Assignment via index positions

# %%
We can do indexing in these data types:
    1) list
    2) str
    3) tuple
    
But Out of above 3, only list is Mutable.

# %%
x = ['apple','mango','kiwi','banana']

# %%
x[0] = 'Sharon'
print(x)
# Out:
# ['Sharon', 'mango', 'kiwi', 'banana']

# %%
x = ('apple','mango','kiwi','banana')

# %%
x[0] = 'Sharon'
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-ee7e407c5837> in <module>
# ----> 1 x[0] = 'Sharon'
#       2 print(x)
#
# TypeError: 'tuple' object does not support item assignment

# %%
x = "mango123#$!"

# %%
x[0] = 'K'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-3e3b8da117df> in <module>
# ----> 1 x[0] = 'K'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # Multidimensional Indexing

# %%
x = ['apple',     'mango']

# %%
x[0]
# Out:
# 'apple'

# %%
x[1]
# Out:
# 'mango'

# %%
y = x[0]
print(y)
# Out:
# apple

# %%
y[0]
# Out:
# 'a'

# %%
x[0][0]
# Out:
# 'a'

# %%
x = [[100,200,300],     [400,500,600]]

# %%
x[0][3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-e97f4d0f7ecd> in <module>
# ----> 1 x[0][3]
#
# IndexError: list index out of range

# %%
x[1][2]
# Out:
# 600

# %%
x = ((100,200,300),     [400,500,600])

# %%
x[1][2]
# Out:
# 600

# %%
x = [{'python':3},{'java':8}]

# %%
x[0]['java']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-b5c60ca9679c> in <module>
# ----> 1 x[0]['java']
#
# KeyError: 'java'

# %%
x[1]['java']
# Out:
# 8

# %%
x = [{'python':[45,55]},{'java':8}]

# %%
x[0]['python'][1]
# Out:
# 55

# %% [markdown]
# ## Object Storage in python

# %%
Everything in Python is an Object.

- All data types are objects.
- functions are objects. (we will learn it later.)
- classes are objects.(we will learn it later.)

# %%
For the following data Types we will always create a separate object:-
    1) list
    2) tuple
    3) dict
    4) set
    
But if the values are same than for the following objects we may not create a separate object, 
and python will assign the existing object in memory.
 1) int
 2) float
 3) bool
 4) str
 5) None
