# %%
assert True

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-a871fdc9ebee> in <module>
# ----> 1 assert False
#
# AssertionError:

# %%
x = 4

# %%
assert x%2 == 0

# %%
assert x%2 == 1
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-74ee771a6c21> in <module>
# ----> 1 assert x%2 == 1
#
# AssertionError:
